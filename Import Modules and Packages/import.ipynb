# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
import numpy as np

np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *

print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from package.maths import addition

addition(4,5)
# Out:
# 9

# %%
from package import maths

maths.addition(4,7)
# Out:
# 11
