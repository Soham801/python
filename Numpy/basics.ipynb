# %%
import numpy as np

np.zeros(11,dtype=int)

np.ones((3,5),dtype=float)

np.full((3,5),3.14)

np.arange(0,21,3)

np.linspace(0,1,5)

np.random.random((5,5))
# Out:
# array([[0.23831882, 0.91417577, 0.44759142, 0.56607714, 0.75143038],
#        [0.07935161, 0.46330119, 0.68805132, 0.89251187, 0.87751798],
#        [0.48704057, 0.60589016, 0.40276318, 0.22237789, 0.49972126],
#        [0.60866235, 0.00964155, 0.91167519, 0.93505901, 0.74072042],
#        [0.91650059, 0.87962118, 0.21805264, 0.32890075, 0.25825215]])
