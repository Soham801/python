# %% [markdown]
# #### File Operation - Read and Write Files
# FIle handling is a crucial part of any programming language. Python provides built-in functions ans methods to read from and write to files , both text and binary.
