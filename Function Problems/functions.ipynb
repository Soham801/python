# %%
f = [4, 32, 212, 100, 0, 28]

converted_temp = list(map(lambda f:((f-32)*5/9), f))

print(converted_temp)
# Out:
# [-15.555555555555555, 0.0, 100.0, 37.77777777777778, -17.77777777777778, -2.2222222222222223]
