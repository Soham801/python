# %%
addition = lambda a,b:a+b

# %%
print(addition(67,34))
# Out:
# 101

# %%
even1 = lambda num:num%2==0

even1(9)
# Out:
# False

# %%
numbers = [1,2,3,4,5,6]

list(map(lambda x:x**2,numbers))
# Out:
# [1, 4, 9, 16, 25, 36]
